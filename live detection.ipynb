# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import winsound
import time
import os

# %%
# Load the trained model
model = load_model('model3.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
open_door_counter = 0
close_door_counter=0
img_size = (256, 256)

# %%
# Define a function to save the image
def save_image(frame, count, status):
    image_filename = f"{status}_door_{count}.jpg"
    cv2.imwrite(image_filename, frame)
    print(f"Saved image: {image_filename}")

# %%
def resize_with_padding(image, target_size=(256, 256)):
    height, width = image.shape[:2]
    target_height, target_width = target_size

    # Calculate padding
    pad_y = max(target_height - height, 0)
    pad_x = max(target_width - width, 0)

    # Apply padding
    top_pad = pad_y // 2
    bottom_pad = pad_y - top_pad
    left_pad = pad_x // 2
    right_pad = pad_x - left_pad

    # Pad the image
    padded_image = cv2.copyMakeBorder(image, top_pad, bottom_pad, left_pad, right_pad, cv2.BORDER_CONSTANT, value=[0, 0, 0])

    # Resize to target size
    resized_image = cv2.resize(padded_image, target_size)

    return resized_image

# %%
def classify_and_alert():
    global open_door_counter, close_door_counter

    # Start the webcam
    cap = cv2.VideoCapture(0)

    # Set the webcam resolution to 800x600
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 800)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 600)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()

        if not ret:
            break

        # Display the original frame
        cv2.imshow('Webcam Feed', frame)

        # Apply padding and resize the image
        processed_image = resize_with_padding(frame, img_size)

        # Normalize and expand dimensions for the model
        image = processed_image / 255.0
        image = np.expand_dims(image, axis=0)

        # Predict using the model
        prediction = model.predict(image)
        class_index = np.argmax(prediction)

        # Print the result and take action
        if class_index == 1:
            print("Door is OPEN")
            winsound.Beep(2000, 150)
            open_door_counter += 1
            if open_door_counter % 5 == 0:
                save_image(frame, open_door_counter, "open")
        else:
            print("Door is CLOSED")
            close_door_counter += 1
            if close_door_counter % 5 == 0:
                save_image(frame, close_door_counter, "closed")

        # Wait for a short time
        time.sleep(0.050)

        # Check if the user wants to quit the application
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture
    cap.release()
    cv2.destroyAllWindows()

# %%
# Start the classification process
classify_and_alert()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# Saved image: closed_door_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is CLOSED
# Saved image: closed_door_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Door is CLOSED
# Saved image: closed_door_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is CLOSED
# Saved image: closed_door_20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is CLOSED
# Saved image: closed_door_25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# Saved image: closed_door_30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Door is CLOSED
# Saved image: closed_door_35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Door is CLOSED
# Saved image: closed_door_40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is CLOSED
# Saved image: closed_door_45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is CLOSED
# Saved image: closed_door_50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# Saved image: closed_door_55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is OPEN
# Saved image: open_door_5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# Saved image: open_door_10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# Saved image: open_door_15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# Saved image: open_door_20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is OPEN
# Saved image: open_door_25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# Saved image: open_door_30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# Saved image: open_door_35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is OPEN
# Saved image: open_door_40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# Saved image: open_door_45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# Saved image: closed_door_60.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# Saved image: closed_door_65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# Saved image: closed_door_70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# Saved image: closed_door_75.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is CLOSED
# Saved image: closed_door_80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# Saved image: closed_door_85.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# Saved image: closed_door_90.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is OPEN
# Saved image: open_door_50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is CLOSED
# Saved image: closed_door_95.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# Saved image: open_door_55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# Saved image: open_door_60.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is OPEN
# Saved image: open_door_65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# Saved image: open_door_70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Door is OPEN
# Saved image: open_door_75.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# Saved image: open_door_80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is OPEN
# Saved image: open_door_85.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# Saved image: closed_door_100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# Saved image: closed_door_105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# Saved image: closed_door_110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Door is CLOSED
# Saved image: closed_door_115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# Saved image: closed_door_120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is CLOSED
# Saved image: closed_door_125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Door is CLOSED
# Saved image: closed_door_130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# Saved image: open_door_90.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is OPEN
# Saved image: open_door_95.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Door is OPEN
# Saved image: open_door_100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is OPEN
# Saved image: open_door_105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Door is OPEN
# Saved image: open_door_110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Door is CLOSED
# Saved image: closed_door_135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Door is CLOSED
# Saved image: closed_door_140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Door is CLOSED
# Saved image: closed_door_145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Door is OPEN
# Saved image: open_door_115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Door is OPEN
# Saved image: open_door_120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is OPEN
# Saved image: open_door_125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is OPEN
# Saved image: open_door_130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# Saved image: open_door_135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Door is OPEN
# Saved image: open_door_140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is OPEN
# Saved image: open_door_145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Door is OPEN
# Saved image: open_door_150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Door is CLOSED
# Saved image: closed_door_150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Door is CLOSED
# Saved image: closed_door_155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Door is OPEN
# Saved image: open_door_155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Door is CLOSED
# Saved image: closed_door_160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Door is CLOSED
# Saved image: closed_door_165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Door is CLOSED
# Saved image: closed_door_170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Door is CLOSED
# Saved image: closed_door_175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Door is CLOSED
# Saved image: closed_door_180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Door is CLOSED
# Saved image: closed_door_185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Door is CLOSED
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Door is OPEN
# Saved image: open_door_160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Door is OPEN
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Door is OPEN
# Saved image: open_door_165.jpg
